# %%
labeling_data = "/home/sung/Desktop/SJH/2022_2R/Segproj/car/labeling/Road data/51011"
source_data = "/home/sung/Desktop/SJH/2022_2R/Segproj/car/source/Road data/51011"

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import torch
import torchvision
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image, ImageDraw
import xml.etree.ElementTree as ET

# %%
Image.open(source_data + "/task51011_004/51011_2021090815535272_056.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
with open(labeling_data + "/task51011_004.xml") as annot_file:
    print(''.join(annot_file.readlines()))
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <annotations>
#   <version>1.1</version>
#   <meta>
#     <task>
#       <id>35507</id>
#       <project>교차로 차량 Points/Polyline 어노테이션</project>
#       <name>task51011_004</name>
#       <size>50</size>
#       <mode>annotation</mode>
#       <overlap>0</overlap>
#       <bugtracker />
#       <flipped>False</flipped>
#       <created>2021-10-18 17:34:43.736221+09:00</created>
#       <updated>2021-11-26 15:35:01.329202+09:00</updated>
#       <start_frame>0</start_frame>
#       <stop_frame>49</stop_frame>
#       <frame_filter>step=1</frame_filter>
#       <labels>
#         <label>
#           <name>unknown</name>
#           <attributes>
#             <attribute>
#               <name>car_count</name>
#               <mutable>False</mutable>
#               <input_type>text</input_type>
#               <default_value>:</default_value>
#               <values>
# </values>
#             </attribute>
#             <attribute>
# ...

# %%
tree = ET.parse(labeling_data + "/task51011_004.xml")
root = tree.getroot()

for sample in root.iter("points") :
    print(sample.items)
# Out:
# <bound method Element.items of <Element 'points' at 0x7f7e2f7fbf40>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f7f93c0>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f7800d0>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f7801f0>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f7804f0>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f780430>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f780850>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f780970>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f780a90>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f780730>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f780d30>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f781120>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f781240>>
# <bound method Element.items of <Element 'points' at 0x7f7e2f781510>>
# ...
